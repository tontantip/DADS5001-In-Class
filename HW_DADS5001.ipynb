14,Everton,8,3,2,3,9,9,0,11,1.38,10.8,11.9,-1.1,-0.13,DLWLL,51883,"Iliman Ndiaye - 3",Jordan Pickford,
15,Leeds United,9,3,2,4,9,14,-5,11,1.22,11.5,9.0,+2.5,+0.28,WLLW,36722,"Joe Rodon, Noah Okafor - 2",Karl Darlow,
16,Fulham,9,2,2,5,9,14,-5,8,0.89,9.0,12.7,-3.8,-0.42,WLLLL,27172,"Raúl Jiménez, Alex Iwobi... - 1",Bernd Leno,
17,Burnley,8,2,1,5,9,15,-6,7,0.88,5.4,15.8,-10.4,-1.31,LDLLL,21521,"Jaidon Anthony - 4",Martin Dúbravka,
18,Nott'ham Forest,8,1,2,5,5,15,-10,5,0.63,8.7,14.1,-5.3,-0.67,LDLLW,30221,"Chris Wood - 2",Matz Sels,
19,West Ham,9,1,1,7,7,20,-13,4,0.44,7.6,14.8,-7.2,-0.80,LLLLL,62457,"Jarrod Bowen - 3",Alphonse Areola,
20,Wolves,8,0,2,6,5,16,-11,2,0.25,6.9,10.0,-3.1,-0.39,LLDDL,30510,"Hwang Hee-chan, Santiago Bueno... - 1","Sam Johnstone, José Sá",
"""

# Read the CSV data from the string into a DataFrame
df = pd.read_csv(io.StringIO(csv_data))

# Set the 'Rk' (Rank) column as the index
df = df.set_index('Rk')

# Drop the 'Notes' column as it is empty
df = df.drop(columns=['Notes'])

df
# Out:
#               Squad  MP  W  D  L  GF  GA  GD  Pts  Pts/MP    xG   xGA   xGD  \
# Rk
# 1           Arsenal   8  6  1  1  15   3  12   19    2.38  13.6   4.7   8.9
# 2        Sunderland   9  5  2  2  11   7   4   17    1.89   8.5  10.4  -2.0
# 3   Manchester City   8  5  1  2  17   6  11   16    2.00  14.4   8.2   6.3
# 4    Manchester Utd   9  5  1  3  15  14   1   16    1.78  16.1  13.6   2.5
# 5       Bournemouth   8  4  3  1  14  11   3   15    1.88  10.4  10.7  -0.3
# 6         Liverpool   9  5  0  4  16  14   2   15    1.67  15.7  11.4   4.2
# 7         Tottenham   8  4  2  2  14   7   7   14    1.75   8.2   9.0  -0.8
# 8           Chelsea   9  4  2  3  17  11   6   14    1.56  13.5  13.0   0.5
# 9    Crystal Palace   8  3  4  1  12   8   4   13    1.63  17.1  10.8   6.3
# 10        Brentford   9  4  1  4  14  14   0   13    1.44  12.9  12.1   0.8
# 11    Newcastle Utd   9  3  3  3   9   8   1   12    1.33  11.8   6.9   4.9
# ...
